# %% [markdown]
# ## Week 2

# %% [markdown]
# ### Exercise:
# Use and experience methods from previous lessons with given data. Try to search for other pandas methods to analyze the data such as `groupby()` and `read_csv()`.

# %%
# You can find covid related data under project's data folder 
base_url = "C:/Users/oztur/deneme-folder/ada-lovelace-academy/data/covid/"
infected_dataset_url = base_url + "time_series_covid19_confirmed_global.csv"
recovered_dataset_url = base_url + "time_series_covid19_recovered_global.csv"
deaths_dataset_url = base_url + "time_series_covid19_deaths_global.csv"

# %% [markdown]
# #### Solution:

# %%
import pandas as pd
import numpy as np

# %%
# Your code goes here
df_infected = pd.read_csv(infected_dataset_url)
df_recovered = pd.read_csv(recovered_dataset_url)
df_deaths = pd.read_csv(deaths_dataset_url)

# %%
df_infected.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...   19551   20342   20917   21459    22142
# 1        0        0        0  ...    1232    1246    1263    1299     1341
# 2        0        0        0  ...   10050   10154   10265   10382    10484
# 3        0        0        0  ...     852     852     852     852      852
# 4        0        0        0  ...      88      91      92      96      113
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# ...

# %%
df_infected.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# 1/22/20             int64
#                    ...
# 6/11/20             int64
# 6/12/20             int64
# 6/13/20             int64
# 6/14/20             int64
# 6/15/20             int64
# Length: 150, dtype: object

# %%
grouped_infected = df_infected.groupby('Country/Region').sum()
print(grouped_infected.head())
# Out:
#                Province/State      Lat     Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan                 0  33.0000  65.0000        0        0        0
# Albania                     0  41.1533  20.1683        0        0        0
# Algeria                     0  28.0339   1.6596        0        0        0
# Andorra                     0  42.5063   1.5218        0        0        0
# Angola                      0 -11.2027  17.8739        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  6/6/20  6/7/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...   19551   20342
# Albania               0        0        0        0  ...    1232    1246
# Algeria               0        0        0        0  ...   10050   10154
# Andorra               0        0        0        0  ...     852     852
# Angola                0        0        0        0  ...      88      91
#
# ...

# %%
grouped_infected = df_infected.groupby('Country/Region').sum()
grouped_recovered = df_recovered.groupby('Country/Region').sum()
grouped_deaths = df_deaths.groupby('Country/Region').sum()

print("Grouped Infected Data:")
print(grouped_infected.head())

print("\nGrouped Recovered Data:")
print(grouped_recovered.head())

print("\nGrouped Deaths Data:")
print(grouped_deaths.head())
# Out:
# Grouped Infected Data:
#                Province/State      Lat     Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan                 0  33.0000  65.0000        0        0        0
# Albania                     0  41.1533  20.1683        0        0        0
# Algeria                     0  28.0339   1.6596        0        0        0
# Andorra                     0  42.5063   1.5218        0        0        0
# Angola                      0 -11.2027  17.8739        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  6/6/20  6/7/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...   19551   20342
# Albania               0        0        0        0  ...    1232    1246
# Algeria               0        0        0        0  ...   10050   10154
# Andorra               0        0        0        0  ...     852     852
# ...

# %%
# Filter data for specific countries
countries = ['US', 'India', 'Brazil']  
filtered_infected = df_infected[df_infected['Country/Region'].isin(countries)]

# Grouping by Country/Region and finding maximum cases for specific dates
max_cases_specific_countries = filtered_infected.groupby('Country/Region')[['6/9/20', '6/13/20']].max()
print("Max Cases for Specific Dates in Selected Countries:")
print(max_cases_specific_countries)
# Out:
# Max Cases for Specific Dates in Selected Countries:
#                  6/9/20  6/13/20
# Country/Region
# Brazil           739503   850514
# India            276146   320922
# US              1979868  2074526

# %%
start_date = '5/1/20'
end_date = '8/1/20'

# Filter the data for the specified time interval and 'Country/Region' column
date_range_columns = df_deaths.columns[(df_deaths.columns >= start_date) & (df_deaths.columns <= end_date)]
filtered_deaths = df_deaths[['Country/Region'] + date_range_columns.tolist()]

# Grouping by Country/Region and finding the sum of deaths for the specified time interval
sum_deaths_time_interval = filtered_deaths.groupby('Country/Region').sum()
print(f"Sum of Deaths for {start_date} to {end_date}:")
print(sum_deaths_time_interval.head())
# Out:
# Sum of Deaths for 5/1/20 to 8/1/20:
#                 5/1/20  5/2/20  5/3/20  5/4/20  5/5/20  5/6/20  5/7/20  \
# Country/Region
# Afghanistan         68      72      85      90      95     104     106
# Albania             31      31      31      31      31      31      31
# Algeria            453     459     463     465     470     476     483
# Andorra             43      44      45      45      46      46      47
# Angola               2       2       2       2       2       2       2
#
#                 5/8/20  5/9/20  5/10/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# Country/Region                           ...
# Afghanistan        109     115      120  ...     327     357     369     384
# Albania             31      31       31  ...      34      34      34      34
# Algeria            488     494      502  ...     698     707     715     724
# Andorra             47      48       48  ...      51      51      51      51
# ...
